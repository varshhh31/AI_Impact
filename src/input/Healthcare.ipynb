# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\VARSHA\OneDrive\Documents\NASO\HC_Outcome_Metrics.csv")

# %%
df.head()
# Out:
#   Outcome_ID  Year Quarter Department                  AI_Tool  Total_Cases  \
# 0   OUT_0001  2020      Q4   Oncology             AI Pathology         8943
# 1   OUT_0002  2022      Q1  Neurology           AI Diagnostics          179
# 2   OUT_0003  2021      Q4  Radiology        AI Drug Discovery         9591
# 3   OUT_0004  2023      Q3        ICU  NLP for Medical Records         1285
# 4   OUT_0005  2022      Q2  Radiology        AI Drug Discovery          191
#
#    AI_Assisted_Cases  AI_Usage_Rate_%  Avg_Diagnosis_Time_min  \
# 0               7040             78.7                    67.0
# 1                 89             49.7                    98.3
# 2               6549             68.3                    75.8
# 3                797             62.0                   110.5
# 4                150             78.5                   102.3
#
#    Readmission_Rate_%  Mortality_Rate_%  False_Positive_Rate_%  \
# 0                16.7              2.01                    5.4
# ...

# %%
df.describe()
# Out:
#               Year  Total_Cases  AI_Assisted_Cases  AI_Usage_Rate_%  \
# count   200.000000   200.000000         200.000000       200.000000
# mean   2021.740000  4866.640000        3108.315000        62.601000
# std       1.338416  2883.873728        2184.112373        18.786885
# min    2020.000000   179.000000          76.000000        30.100000
# 25%    2021.000000  2538.750000        1190.250000        46.450000
# 50%    2022.000000  4893.000000        2810.000000        62.850000
# 75%    2023.000000  7114.500000        4432.250000        77.750000
# max    2024.000000  9914.000000        9270.000000        95.000000
#
#        Avg_Diagnosis_Time_min  Readmission_Rate_%  Mortality_Rate_%  \
# count              200.000000          200.000000        200.000000
# mean                61.321500           11.353000          4.086250
# std                 32.627594            4.621296          2.176816
# min                  6.700000            3.000000          0.520000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Outcome_ID                        200 non-null    object
#  1   Year                              200 non-null    int64
#  2   Quarter                           200 non-null    object
#  3   Department                        200 non-null    object
#  4   AI_Tool                           200 non-null    object
#  5   Total_Cases                       200 non-null    int64
#  6   AI_Assisted_Cases                 200 non-null    int64
#  7   AI_Usage_Rate_%                   200 non-null    float64
#  8   Avg_Diagnosis_Time_min            200 non-null    float64
#  9   Readmission_Rate_%                200 non-null    float64
#  10  Mortality_Rate_%                  200 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Outcome_ID                          0
# Year                                0
# Quarter                             0
# Department                          0
# AI_Tool                             0
# Total_Cases                         0
# AI_Assisted_Cases                   0
# AI_Usage_Rate_%                     0
# Avg_Diagnosis_Time_min              0
# Readmission_Rate_%                  0
# Mortality_Rate_%                    0
# False_Positive_Rate_%               0
# False_Negative_Rate_%               0
# Cost_Per_Case_USD                   0
# Patient_Wait_Time_min               0
# Staff_Efficiency_Score              0
# AI_Recommendation_Accepted_%        0
# Critical_Alert_Response_Time_min    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["AI_Tool"] = df["AI_Tool"].str.strip()

# %%
df.head()
# Out:
#   Outcome_ID  Year Quarter Department                  AI_Tool  Total_Cases  \
# 0   OUT_0001  2020      Q4   Oncology             AI Pathology         8943
# 1   OUT_0002  2022      Q1  Neurology           AI Diagnostics          179
# 2   OUT_0003  2021      Q4  Radiology        AI Drug Discovery         9591
# 3   OUT_0004  2023      Q3        ICU  NLP for Medical Records         1285
# 4   OUT_0005  2022      Q2  Radiology        AI Drug Discovery          191
#
#    AI_Assisted_Cases  AI_Usage_Rate_%  Avg_Diagnosis_Time_min  \
# 0               7040             78.7                    67.0
# 1                 89             49.7                    98.3
# 2               6549             68.3                    75.8
# 3                797             62.0                   110.5
# 4                150             78.5                   102.3
#
#    Readmission_Rate_%  Mortality_Rate_%  False_Positive_Rate_%  \
# 0                16.7              2.01                    5.4
# ...

# %% [markdown]
# df = df.drop(columns=["Outcome_ID"])

# %%
df = df.drop(columns=["Outcome_ID"])

# %%
df.to_csv("Healthcare.csv", index=False)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\VARSHA\OneDrive\Documents\NASO\Impact_of_AI_on_Education_Responses.xlsx")

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
#   1.What best describes you?                                                                                                 0
#   2. What is your level of education?                                                                                        0
# 3. Age Group                                                                                                                 0
# 4. Gender                                                                                                                    0
#  5. Do you use AI tools for learning or teaching?                                                                            0
# 6. Which AI tools do you use most frequently? (Select all that apply)                                                        0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                 Timestamp             1.What best describes you?    \
# 0 2026-06-17 13:01:33.555  Working Professional pursuing education
# 1 2026-06-17 13:04:36.361                                 Working
# 2 2026-06-17 13:07:02.827                          College Student
# 3 2026-06-17 13:12:58.707                          College Student
# 4 2026-06-17 13:14:43.424                          College Student
#
#     2. What is your level of education?   3. Age Group 4. Gender  \
# 0                           Undergraduate  21–30 years      Male
# 1                            Postgraduate  21–30 years      Male
# 2                            Postgraduate  21–30 years      Male
# 3                            Postgraduate  21–30 years    Female
# 4                            Postgraduate  21–30 years      Male
#
#    5. Do you use AI tools for learning or teaching?    \
# 0                                                Yes
# 1                                                Yes
# ...

# %%
df.head()
# Out:
#                 Timestamp             1.What best describes you?    \
# 0 2026-06-17 13:01:33.555  Working Professional pursuing education
# 1 2026-06-17 13:04:36.361                                 Working
# 2 2026-06-17 13:07:02.827                          College Student
# 3 2026-06-17 13:12:58.707                          College Student
# 4 2026-06-17 13:14:43.424                          College Student
#
#     2. What is your level of education?   3. Age Group 4. Gender  \
# 0                           Undergraduate  21–30 years      Male
# 1                            Postgraduate  21–30 years      Male
# 2                            Postgraduate  21–30 years      Male
# 3                            Postgraduate  21–30 years    Female
# 4                            Postgraduate  21–30 years      Male
#
#    5. Do you use AI tools for learning or teaching?    \
# 0                                                Yes
# 1                                                Yes
# ...

# %%
print(df.columns)
# Out:
# Index(['Timestamp', '  1.What best describes you?  ',
#        '  2. What is your level of education?  ', '3. Age Group', '4. Gender',
#        ' 5. Do you use AI tools for learning or teaching?  ',
#        '6. Which AI tools do you use most frequently? (Select all that apply)',
#        '  7. How often do you use AI in your studies or teaching?  ',
#        '  8. Has AI improved your learning or teaching experience?  ',
#        '  9. Approximately how much time does AI save you each week for studying, preparing lessons, or completing assignments?  ',
#        '  10. AI helps me understand difficult concepts more effectively.  ',
#        '  11. Which educational benefit of AI do you value the most?  ',
#        '  12. Do you believe AI helps improve employability by supporting skill development?  ',
#        '  13. Do you think excessive use of AI reduces students' critical thinking and creativity?  ',
# ...

# %%
df.to_csv("Education.csv", index=False)

# %%
df = df.rename(columns={
    "9. Approximately how much time does AI save you each week for studying, preparing lessons, or completing assignments?": "9. AI_Time_Saved"
})

# %%
# Remove the Timestamp column
df = df.drop(columns=["Timestamp"])

# Rename all remaining columns with short names
df.columns = [
    "Description",
    "Education_Level",
    "Age_Group",
    "Gender",
    "Uses_AI_for_Learning",
    "AI_Tools_Used",
    "AI_Usage_Frequency",
    "AI_Improved_Experience",
    "AI_Time_Saved",
    "AI_Concept_Understanding",
    "AI_Educational_Benefit",
    "AI_Employability_Impact",
    "AI_Critical_Thinking_Impact",
    "AI_Misuse_Concern",
    "Privacy_Security_Concern",
    "AI_Training_Needed",
    "Overall_AI_Impact"
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Remove the Timestamp column
# ----> 2 df = df.drop(columns=["Timestamp"])
#       4 # Rename all remaining columns with short names
#       5 df.columns = [
#       6     "Description",
#       7     "Education_Level",
#    (...)
#      22     "Overall_AI_Impact"
#      23 ]
#
# File c:\Users\VARSHA\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
# ...

# %%
print(df.columns)
# Out:
# Index(['Description', 'Education_Level', 'Age_Group', 'Gender',
#        'Uses_AI_for_Learning', 'AI_Tools_Used', 'AI_Usage_Frequency',
#        'AI_Improved_Experience', 'AI_Time_Saved', 'AI_Concept_Understanding',
#        'AI_Educational_Benefit', 'AI_Employability_Impact',
#        'AI_Critical_Thinking_Impact', 'AI_Misuse_Concern',
#        'Privacy_Security_Concern', 'AI_Training_Needed', 'Overall_AI_Impact'],
#       dtype='object')

# %%
# Out:
# Index(['Timestamp', '1.What best describes you?',
#        '2. What is your level of education?', '3. Age Group', '4. Gender',
#        '6. AI_Tools_Used',
#        '7. How often do you use AI in your studies or teaching?',
#        '8. Has AI improved your learning or teaching experience?',
#        '9. Approximately how much time does AI save you each week for studying, preparing lessons, or completing assignments?',
#        '10. AI helps me understand difficult concepts more effectively.',
#        '11. Which educational benefit of AI do you value the most?',
#        '12. Do you believe AI helps improve employability by supporting skill development?',
#        '13. Do you think excessive use of AI reduces students' critical thinking and creativity?',
#        '14.  Are you concerned that students may misuse AI for assignments or examinations?',
#        '15.  How concerned are you about privacy and data security while using AI-based educational platforms?',
# ...

# %%
df.to_csv("Education.csv", index=False)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\VARSHA\OneDrive\Documents\NASO\AI_Adoption_Agriculture.csv")

# %%
df.isnull().sum()
# Out:
# Year                     0
# State                    0
# Crop_Type                0
# AI_Tool_Used             0
# Adoption_Rate_Pct        0
# Yield_Improvement_Pct    0
# Cost_Reduction_Pct       0
# Farmers_Using_AI         0
# Govt_Scheme_Support      0
# Investment_Cr            0
# dtype: int64

# %%
df.head()
# Out:
#    Year        State     Crop_Type     AI_Tool_Used  Adoption_Rate_Pct  \
# 0  2019       Punjab         Wheat   Drone Spraying                 12
# 1  2019  Maharashtra        Cotton     Soil Sensors                 10
# 2  2019   Tamil Nadu          Rice       Weather AI                 15
# 3  2019           UP     Sugarcane  Crop Monitoring                  8
# 4  2019    Karnataka  Horticulture    AI Irrigation                 18
#
#    Yield_Improvement_Pct  Cost_Reduction_Pct  Farmers_Using_AI  \
# 0                      8                   5             42000
# 1                      6                   4             35000
# 2                     10                   7             58000
# 3                      5                   3             29000
# 4                     12                   9             21000
#
#   Govt_Scheme_Support  Investment_Cr
# 0            PM-KISAN            120
# 1       Digital India             95
# 2         ICAR Scheme            140
# ...

# %%
df.tail()
# Out:
#     Year        State     Crop_Type   AI_Tool_Used  Adoption_Rate_Pct  \
# 30  2025       Punjab         Wheat     AI + Drone                 62
# 31  2025  Maharashtra        Cotton      AI + Soil                 54
# 32  2025   Tamil Nadu          Rice  Full AI Stack                 70
# 33  2025           UP     Sugarcane    AI Platform                 47
# 34  2025    Karnataka  Horticulture  Smart Agri AI                 73
#
#     Yield_Improvement_Pct  Cost_Reduction_Pct  Farmers_Using_AI  \
# 30                     38                  29            224000
# 31                     34                  24            190000
# 32                     44                  33            298000
# 33                     30                  22            154000
# 34                     46                  35            112000
#
#    Govt_Scheme_Support  Investment_Cr
# 30            PM-KISAN            800
# 31       Digital India            615
# 32         ICAR Scheme            860
# ...

# %%
df.describe()
# Out:
#               Year  Adoption_Rate_Pct  Yield_Improvement_Pct  \
# count    35.000000          35.000000              35.000000
# mean   2022.000000          35.171429              22.285714
# std       2.029199          18.142387              11.354117
# min    2019.000000           8.000000               5.000000
# 25%    2020.000000          20.000000              13.000000
# 50%    2022.000000          33.000000              21.000000
# 75%    2024.000000          48.000000              30.500000
# max    2025.000000          73.000000              46.000000
#
#        Cost_Reduction_Pct  Farmers_Using_AI  Investment_Cr
# count           35.000000         35.000000      35.000000
# mean            16.200000     110771.428571     364.142857
# std              8.750798      68446.666964     216.562332
# min              3.000000      21000.000000      80.000000
# 25%              9.000000      59500.000000     180.000000
# 50%             16.000000      96000.000000     320.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("Agriculture_Clean.csv", index=False)

# %%
print(len(df))
# Out:
# 35

# %%
print(df)
# Out:
#     Year        State     Crop_Type       AI_Tool_Used  Adoption_Rate_Pct  \
# 0   2019       Punjab         Wheat     Drone Spraying                 12
# 1   2019  Maharashtra        Cotton       Soil Sensors                 10
# 2   2019   Tamil Nadu          Rice         Weather AI                 15
# 3   2019           UP     Sugarcane    Crop Monitoring                  8
# 4   2019    Karnataka  Horticulture      AI Irrigation                 18
# 5   2020       Punjab         Wheat     Drone Spraying                 18
# 6   2020  Maharashtra        Cotton       Soil Sensors                 15
# 7   2020   Tamil Nadu          Rice         Weather AI                 22
# 8   2020           UP     Sugarcane    Crop Monitoring                 12
# 9   2020    Karnataka  Horticulture      AI Irrigation                 25
# 10  2021       Punjab         Wheat  Precision Farming                 26
# 11  2021  Maharashtra        Cotton  Pest Detection AI                 22
# ...

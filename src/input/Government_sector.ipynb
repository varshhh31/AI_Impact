# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\VARSHA\OneDrive\Documents\NASO\AI_Impact\data\government_sector\GOV_Service_Delivery_Metrics.csv")

# %%
df.head()
# Out:
#   Metric_ID  Year Quarter          Service_Type  \
# 0  SVC_0001  2023      Q2   Grievance Redressal
# 1  SVC_0002  2019      Q4    Healthcare Schemes
# 2  SVC_0003  2022      Q4  Subsidy Distribution
# 3  SVC_0004  2021      Q3   Grievance Redressal
# 4  SVC_0005  2020      Q3    Healthcare Schemes
#
#              Ministry_Department         Region  Total_Requests  \
# 0      Ministry of Law & Justice     East India          167119
# 1  Ministry of Rural Development     East India          183698
# 2  Ministry of Rural Development  Central India          260012
# 3             Ministry of Health    South India           94532
# 4  Ministry of Skill Development     East India           43758
#
#    AI_Processed_Requests  Resolved_Requests  Resolution_Rate_%  \
# 0                 117721              88609               53.0
# 1                  65230             140187               76.3
# 2                  56026             208236               80.1
# ...

# %%
df.describe()
# Out:
#               Year  Total_Requests  AI_Processed_Requests  Resolved_Requests  \
# count   200.000000      200.000000             200.000000         200.000000
# mean   2021.360000   270841.225000          148055.180000      201116.700000
# std       1.680632   137663.737094           96654.295675      110617.891065
# min    2019.000000     2163.000000             577.000000        1442.000000
# 25%    2020.000000   176210.250000           72371.250000      117383.000000
# 50%    2021.000000   270856.500000          126753.000000      195150.000000
# 75%    2023.000000   403640.750000          212831.250000      270170.500000
# max    2024.000000   498662.000000          393644.000000      474714.000000
#
#        Resolution_Rate_%  Avg_Processing_Time_Days  Error_Rate_%  \
# count         200.000000                200.000000    200.000000
# mean           74.304000                 16.078000      8.164000
# std            14.744919                  8.796443      4.395133
# ...

# %%
df.isnull().sum()
# Out:
# Metric_ID                      0
# Year                           0
# Quarter                        0
# Service_Type                   0
# Ministry_Department            0
# Region                         0
# Total_Requests                 0
# AI_Processed_Requests          0
# Resolved_Requests              0
# Resolution_Rate_%              0
# Avg_Processing_Time_Days       0
# Error_Rate_%                   0
# Cost_Per_Request_INR           0
# Citizen_Complaints             0
# Repeat_Requests_%              0
# Digital_Adoption_Rate_%        0
# Fraud_Cases_Detected           0
# Fraud_Amount_Saved_Lakh_INR    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("Government_sector_Clean.csv", index=False)

# %%
df = df.drop(columns=["Metric_ID"])

# %%
df.to_csv("Government_sector.csv", index=False)
